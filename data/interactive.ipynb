# %%
import pandas as pd
import numpy as np
import os
import shutil
import matplotlib.pyplot as plt

# %%
images_folder = "/mnt/DGXUserData/dxm060/Zach_Analysis/petlymph_image_data/final_2.5d_images_and_labels/output_coronal_images_v2"
labels_folder = "/mnt/DGXUserData/dxm060/Zach_Analysis/petlymph_image_data/final_2.5d_images_and_labels/output_coronal_labels_v2"
train_folder = "/mnt/DGXUserData/dxm060/Zach_Analysis/uw_lymphoma_pet_3d/dataframes/training.xlsx"
val_folder = "/mnt/DGXUserData/dxm060/Zach_Analysis/uw_lymphoma_pet_3d/dataframes/validation.xlsx"
test_folder = "/mnt/DGXUserData/dxm060/Zach_Analysis/uw_lymphoma_pet_3d/dataframes/testing.xlsx"
heap = "./heap"

# %%
df = pd.read_excel(train_folder)
df = df.sort_values(by="label_name")
df.set_index("label_name", inplace=True)

# %%
df.head()
# Out:
#                                                                      image  \
# label_name
# PETWB_000003_02_label_1  /mnt/Bradshaw/UW_PET_Data/resampled_cropped_im...
# PETWB_000003_02_label_2  /mnt/Bradshaw/UW_PET_Data/resampled_cropped_im...
# PETWB_000003_02_label_3  /mnt/Bradshaw/UW_PET_Data/resampled_cropped_im...
# PETWB_000003_04_label_1  /mnt/Bradshaw/UW_PET_Data/resampled_cropped_im...
# PETWB_000003_05_label_1  /mnt/Bradshaw/UW_PET_Data/resampled_cropped_im...
#
#                                                                     image2  \
# label_name
# PETWB_000003_02_label_1  /mnt/Bradshaw/UW_PET_Data/resampled_cropped_im...
# PETWB_000003_02_label_2  /mnt/Bradshaw/UW_PET_Data/resampled_cropped_im...
# PETWB_000003_02_label_3  /mnt/Bradshaw/UW_PET_Data/resampled_cropped_im...
# PETWB_000003_04_label_1  /mnt/Bradshaw/UW_PET_Data/resampled_cropped_im...
# PETWB_000003_05_label_1  /mnt/Bradshaw/UW_PET_Data/resampled_cropped_im...
#
#                                                                      label  \
# label_name
# PETWB_000003_02_label_1  /mnt/Bradshaw/UW_PET_Data/resampled_cropped_im...
# PETWB_000003_02_label_2  /mnt/Bradshaw/UW_PET_Data/resampled_cropped_im...
# PETWB_000003_02_label_3  /mnt/Bradshaw/UW_PET_Data/resampled_cropped_im...
# PETWB_000003_04_label_1  /mnt/Bradshaw/UW_PET_Data/resampled_cropped_im...
# PETWB_000003_05_label_1  /mnt/Bradshaw/UW_PET_Data/resampled_cropped_im...
#
#                                                                     report  \
# label_name
# PETWB_000003_02_label_1  There is also interval increase in the size an...
# PETWB_000003_02_label_2  Also, the left adrenal nodule (slice ) increas...
# PETWB_000003_02_label_3  A new mildly hypermetabolic subcutaneous nodul...
# PETWB_000003_04_label_1  Abdomen/Pelvis:…There is interval new intensel...
# PETWB_000003_05_label_1  Chest:…There has been decrease in the right-si...
#
#                          slice_num  suv_num  patient_id
# label_name
# PETWB_000003_02_label_1        169      6.1           3
# PETWB_000003_02_label_2        191      7.7           3
# PETWB_000003_02_label_3        223      3.2           3
# PETWB_000003_04_label_1        194     20.0           3
# PETWB_000003_05_label_1        149      4.3           3
